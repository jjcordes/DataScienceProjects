# %%
import pandas as pd
import numpy as np
df = pd.DataFrame.from_csv('df_v5.csv')
df['los_hr'] = df.maxlos/24
df['countloc_cat'] = df.loc_cat
df = df.drop(['unique_discharge_dispo','unique_discharge_dispo_p1','unique_discharge_dispo1','unique_concatabdominal_assess','unique_concatabdominal_assess_p1','unique_concatcart_loc','unique_concatcart_loc_p1','unique_concatinitialrhythm','unique_concatinitialrhythm_p1','unique_concatmed_name_substr','unique_concatmed_name_substr_p1','unique_concatreason','unique_concatreason1','unique_concatreason_p1','group_concat(loc_cat)','group_concat(cardiac_rhythm)','concat_cardiac_rhythm','concat_loc_cat','concatabdominal_assess','concatabdominal_assess_p1','concatcart_loc','concatcart_loc_p1','concatdischarge_dispo','concatdischarge_dispo1','concatdischarge_dispo_p1','concatinitialrhythm','concatinitialrhythm_p1','concatmed_name_substr','concatmed_name_substr_p1','concatreason','concatreason1','concatreason_p1','maxammonia','maxammonia_p1','maxroute','maxroute_p1','maxsex','mincardiac_rhythm','mincardiac_rhythm_p1','minenc_eio','minenc_eio_p1','minethnicity','minmed_name','minmed_name_p1','minrace','unique_cardiac_r'], axis=1)
#df = df.drop(['loc_cat','patient_id','encounter_id_x','minseason_x','maxseason_x','maxseason_p1_x','minseason_p1_x','maxseason1_x','minseason1_x','maxday_p1','maxday','maxtransfer_order1','maxwardorICU1','minrass1','maxtreatment_limit1','maxwardorICU1','maxeverwardorICU1','maxnum_icustays1','minalt1','patient_id_x','patient_id_sep','pat_enc','maxday_y','maxday1','min(day_to_read)','septic_enc','read_enc','encounter_id1', 'encounter_id_p1','2','1','minday','1m_read','1y_6m_noread','1y_noread','2m_read','2y_noread','3m_read','6m_noread','patient_id_y','maxadmission_order1'], axis=1)
df.maxdrip_dobutamine.max()
df = df[df['maxdrip_dobutamine']!= 14365.1]
#NORMAL RANGE OF PROTEIN BETWEEN 6-8.3, OTHER DEPENDENCIES 
df['protein_oor'] = df.maxtotal_protein.fillna(0) - 7.15 
df['protein_oor_p1'] = df.maxtotal_protein_p1.fillna(0) - 7.15
#CHECK THAT WE DON'T HAVE TO MAKE AN EQUATION
df['avgmeds_per_day'] = df['countmed_name']/df['los_hr']
#df['avgmeds_per_day'] = df['countmed_name_p1']/df['los_hr_p1'] --- will need to compute los_hr_p1
##SECOND ITERATION##
#REMOVE RACE UNKNOWN -- VERY ODD THAT THIS IS ASSOCIATED WITH READ
df = df.drop(['race_unknown'], axis=1)
df['maxbraden_scale'] = df.maxbraden_scale.fillna(25)

#REMOVE ALL FEAT LESS THAN 10
# Out:
# C:\Users\Jay\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   app.launch_new_instance()
# C:\Users\Jay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2825: DtypeWarning: Columns (230,232,235,237,239,242,309,310,677,812,826,863) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df['maxbraden_scale_p1'] = df.maxbraden_scale_p1.fillna(25)
df['avgbraden_scale_p1'] = df.avgbraden_scale_p1.fillna(25)
df['maxbraden_mobility_p1'] = df.maxbraden_mobility_p1.fillna(5)
df['minbraden_mobility_p1'] = df.minbraden_mobility_p1.fillna(5)
df['maxbraden_friction_p1'] = df.maxbraden_friction_p1.fillna(4)
df['minbraden_friction_p1'] = df.minbraden_friction_p1.fillna(4)
df['maxbraden_activity_p1'] = df.maxbraden_activity_p1.fillna(5)
df['minbraden_activity_p1'] = df.minbraden_activity_p1.fillna(5)
df['maxbraden_moisture_p1'] = df.maxbraden_moisture_p1.fillna(5)
df['minbraden_moisture_p1'] = df.minbraden_moisture_p1.fillna(5)
df['maxbraden_sensory_p1'] = df.maxbraden_sensory_p1.fillna(5)
df['minbraden_sensory_p1'] = df.minbraden_sensory_p1.fillna(5)
df['maxbraden_nutrition_p1'] = df.maxbraden_nutrition_p1.fillna(5)
df['minbraden_nutrition_p1'] = df.minbraden_nutrition_p1.fillna(5)
df['maxbraden_scale_p1'] = df.maxbraden_scale_p1.fillna(25)
df['avgbraden_scale_p1'] = df.avgbraden_scale_p1.fillna(25)
df['maxbraden_mobility_p1'] = df.maxbraden_mobility_p1.fillna(5)
df['minbraden_mobility_p1'] = df.minbraden_mobility_p1.fillna(5)
df['maxbraden_friction_p1'] = df.maxbraden_friction_p1.fillna(4)
df['minbraden_friction_p1'] = df.minbraden_friction_p1.fillna(4)
df['maxbraden_activity_p1'] = df.maxbraden_activity_p1.fillna(5)
df['minbraden_activity_p1'] = df.minbraden_activity_p1.fillna(5)
df['maxbraden_moisture_p1'] = df.maxbraden_moisture_p1.fillna(5)
df['minbraden_moisture_p1'] = df.minbraden_moisture_p1.fillna(5)
df['maxbraden_nutrition_p1'] = df.maxbraden_nutrition_p1.fillna(5)
df['minbraden_nutrition_p1'] = df.minbraden_nutrition_p1.fillna(5)
df['maxbraden_sensory_p1'] = df.maxbraden_sensory_p1.fillna(5)
df['minbraden_sensory_p1'] = df.minbraden_sensory_p1.fillna(5)

# %%
df = df.drop(['maxage_yr', 'maxage_yr_p1',
              'maxdied01','maxdied011','max_los_total',
             'avg_los_total', 'max_temp_c', 'min_temp_c',
             'avg_temp_c', 'maxtemp', 'mintemp'], axis=1)

# %%
df['maxgcs_score'] = df.maxgcs_score.fillna(16)
df['maxgcs_eye'] = df.maxgcs_eye.fillna(5)
df['mingcs_eye'] = df.mingcs_eye.fillna(5)
df['maxgcs_motor'] = df.mingcs_motor.fillna(7)
df['mingcs_motor'] = df.mingcs_motor.fillna(7)
df['maxgcs_verbal'] = df.maxgcs_verbal.fillna(6)
df['mingcs_verbal'] = df.mingcs_verbal.fillna(6)
df['maxgcs_score_p1'] = df.maxgcs_score_p1.fillna(16)
df['maxgcs_eye_p1'] = df.maxgcs_eye_p1.fillna(5)
df['mingcs_eye_p1'] = df.mingcs_eye_p1.fillna(5)
df['maxgcs_motor_p1'] = df.mingcs_motor_p1.fillna(7)
df['mingcs_motor_p1'] = df.mingcs_motor_p1.fillna(7)
df['maxgcs_verbal_p1'] = df.maxgcs_verbal_p1.fillna(6)
df['mingcs_verbal_p1'] = df.mingcs_verbal_p1.fillna(6)
df.mingcs_verbal_p1.describe()
# Out:
# count    52207.000000
# mean         5.832206
# std          0.624036
# min          1.000000
# 25%          6.000000
# 50%          6.000000
# 75%          6.000000
# max          6.000000
# Name: mingcs_verbal_p1, dtype: float64

# %%
df['maxmorse_ambaid'] = df.maxmorse_ambaid.fillna(0)
df['maxmorse_fallhistory'] = df.maxmorse_fallhistory.fillna(0)
df['maxmorse_gaittransfer'] = df.maxmorse_gaittransfer.fillna(0)
df['maxmorse_ivdevice'] = df.maxmorse_ivdevice.fillna(0)
df['maxmorse_mentalstatus'] = df.maxmorse_mentalstatus.fillna(0)
#df['minmorse_dateoffall'] = df.minmorse_dateoffall.fillna(0)
df['minmorse_ambaid'] = df.minmorse_ambaid.fillna(0)
df['minmorse_fallhistory'] = df.minmorse_fallhistory.fillna(0)
df['minmorse_gaittransfer'] = df.minmorse_gaittransfer.fillna(0)
df['minmorse_ivdevice'] = df.minmorse_ivdevice.fillna(0)
df['minmorse_mentalstatus'] = df.minmorse_mentalstatus.fillna(0)
df['maxmorse_score'] = df.maxmorse_score.fillna(0)
df['maxmorse_ambaid_p1'] = df.maxmorse_ambaid_p1.fillna(0)
df['maxmorse_fallhistory_p1'] = df.maxmorse_fallhistory_p1.fillna(0)
df['maxmorse_gaittransfer_p1'] = df.maxmorse_gaittransfer_p1.fillna(0)
df['maxmorse_ivdevice_p1'] = df.maxmorse_ivdevice_p1.fillna(0)
df['maxmorse_mentalstatus_p1'] = df.maxmorse_mentalstatus_p1.fillna(0)
#df['minmorse_dateoffall'] = df.minmorse_dateoffall.fillna(0)
df['minmorse_ambaid_p1'] = df.minmorse_ambaid_p1.fillna(0)
df['minmorse_fallhistory_p1'] = df.minmorse_fallhistory_p1.fillna(0)
df['minmorse_gaittransfer_p1'] = df.minmorse_gaittransfer_p1.fillna(0)
df['minmorse_ivdevice_p1'] = df.minmorse_ivdevice_p1.fillna(0)
df['minmorse_mentalstatus_p1'] = df.minmorse_mentalstatus_p1.fillna(0)
df['maxmorse_score_p1'] = df.maxmorse_score_p1.fillna(0)

# %%
df['avgIVF_volume'] = df.avgIVF_volume.fillna(0)
df['avgIVF_volume_p1'] = df.avgIVF_volume_p1.fillna(0)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52207 entries, 0 to 52208
# Columns: 992 entries, 1 to avgmeds_per_day
# dtypes: bool(7), float64(919), int64(66)
# memory usage: 393.1 MB

# %%
df['sofa_taken'] = df.maxsofa.fillna(0)

#PRIOR VISIT
df['mobility_p1'] = df.summob_lo_p1.fillna(0)
df['sumelix_comorb_p1'] = df.sumelix_comorb_p1.fillna(0)
#sums come in extremes

df['logsum_elix_comorb'] = np.log(df.sumelix_comorb + 1 )
df['logsum_elix_comorb_p1'] = np.log(df.sumelix_comorb_p1 + 1)

# %%
col = list(df.columns)
for x in col:
    if x[-1] == '1':
        col.remove(x)
no_p1 = x

no_p1 = ['1m_read', '1y_6m_noread', '1y_noread', 
             '2', '2m_read', '2y_noread', '3m_read', 
             '6m_noread', 'avgIVF_volume', 'avgabs_bands', 
             'avgabs_neutrophils', 'avgalbumin_c', 
             'avgallphos_c', 'avgalt', 'avgammonia', 
             'avgantitrypsin', 'avgavpu_c', 'avgbands', 
             'avgbasophils', 'avgblasts', 'avgbmi', 
             'avgbraden_scale', 'avgbun_c', 
             'avgbun_cr_c', 'avgcalcium_c', 
             'avgchloride', 'avgco2_c', 'avgcortisol', 
             'avgcreatinine_c', 'avgcrp', 'avgdbp_c', 
             'avgdrip_dexmedetomidine', 'avgdrip_dobutamine', 
             'avgdrip_dopamine', 'avgdrip_fentanyl', 
             'avgdrip_midazolam', 'avgdrip_milrinone', 
             'avgdrip_morphine', 'avgdrip_norepinephrine', 
             'avgdrip_phenylephrine', 'avgdrip_propofol', 
             'avgdrip_vasopressin', 'avgecart_score', 
             'avgelix_comorb', 'avgencount_enum', 'avgeosinophils', 
             'avgesr', 'avgfio2', 'avgfio2_vent', 'avggastric_output', 
             'avggcs_score', 'avggluc_ser_c', 'avghb1198', 
             'avghb1200', 'avghb_c', 'avghc03_ven', 
             'avgheadneck_w_ct', 'avgheadneck_wo_ct', 
             'avghematocrit', 'avghfo_fio2', 'avghr_c', 
             'avginr', 'avgketones', 'avglactate', 
             'avglactate1_p1', 'avglactate_wholebld1434', 
             'avglactate_wholebld4303', 'avglactic_acid', 
             'avglipase_p1', 'avglos', 'avglos_total', 
             'avglymphocytes', 'avgmagnesium', 'avgmap_notcalc', 
             'avgmap_zzz', 'avgmcv', 'avgmetamyelocytes', 
             'avgmonocytes', 'avgmorse_score', 'avgneutrophils', 
             'avgni_fio2', 'avgnrbc', 'avgo2_flow', 'avgo2sat_c', 
             'avgosmolality', 'avgpaco2', 'avgpain_scale', 'avgpao2', 
             'avgph1250', 'avgph1819', 'avgph272', 'avgph4315', 
             'avgph690', 'avgphosphate', 'avgplatelet_count_c', 
             'avgpotassium_c', 'avgppi_c', 'avgpromyelocytes', 
             'avgptt', 'avgrass', 'avgrbc', 'avgrdw', 'avgrr_c', 
             'avgsbp_c', 'avgsf_ratio', 'avgsf_ratio_old', 
             'avgsf_ratio_p1', 'avgsgot_c', 'avgsodium_c', 'avgsofa_score', 
             'avgsvo2_2641', 'avgsvo2_4351', 'avgtemp_c', 'avgtemp_c_ecart', 
             'avgtemp_c_p1', 'avgtotal_protein', 'avgtroponin_bin', 
             'avgtroponin_old', 'avgtube_output', 'avgwbc_c', 
             'avgwound_output', 'countIVF_meds', 'countabdominal_assess', 
             'countcart', 'countcart_loc', 'countcart_p1', 'countcentral_line', 
             'countenc_eio', 'countmed_name', 'countroute', 'day_to_read', 
             'days_prior', 'diffbmi', 'encounter_id_x', 'encounter_id_p1', 
             'hr_c', 'lipase', 'loc_cat', 'maxIVF_meds', 'maxIVF_volume', 
             'maxIV_intake', 'maxabs_bands', 'maxabs_neutrophil_p1', 
             'maxabs_neutrophils', 'maxabx_cont_washout', 'maxabx_day_flag', 
             'maxabx_flag', 'maxabx_sum_1day', 'maxabx_sum_2day', 
             'maxabx_sum_3day', 'maxabx_sum_4day', 'maxabx_washout', 
             'maxadmission_order', 'maxadmission_order_p1', 'maxaed_med', 
             'maxage', 'maxage_p1', 'maxalt', 'maxantiarrhythmic_ad', 
             'maxanticoag_ad', 'maxantipsych_ad', 'maxantitrypsin', 'maxantiviral_ad', 
             'maxauto_abs_neutrophils', 'maxavnodal_ad', 'maxbands', 'maxbasophils', 
             'maxbenzo_diaz', 'maxbipap', 'maxblasts', 'maxbraden_activity', 
             'maxbraden_friction', 'maxbraden_mobility', 'maxbraden_moisture', 
             'maxbraden_nutrition', 'maxbraden_scale', 'maxbraden_sensory', 
             'maxcardiac_rhythm', 'maxcdiff', 'maxchloride', 'maxcontam_true', 
             'maxcortisol', 'maxcpap', 'maxcrp', 'maxct_chestabdpelviswo', 
             'maxct_chesupabd', 'maxct_lowextrem_w', 'maxct_lowextrem_wo', 
             'maxct_w_contrast', 'maxct_wo_contrast', 'maxcul_blood_ord', 
             'maxcul_cathtip', 'maxcul_csf', 'maxcul_influenza', 'maxcul_mrsa', 
             'maxcul_other_ord', 'maxcul_parainfluenza', 'maxcul_resp', 
             'maxcul_stool_ord', 'maxcul_urine_ord', 'maxculblood_range', 
             'maxday', 'maxday_p1', 'maxday_y', 'maxdialysis', 'maxdied01_p1', 
             'maxdied_ever', 'maxdied_ever_p1', 'maxdiuretic_ad', 
             'maxdrip_dexmedetomidine', 'maxdrip_dobutamine', 'maxdrip_dopamine', 
             'maxdrip_fentanyl', 'maxdrip_midazolam', 'maxdrip_milrinone', 
             'maxdrip_morphine', 'maxdrip_norepinephrine', 'maxdrip_phenylephrine', 
             'maxdrip_propofol', 'maxdrip_vasopressin', 'maxecart_score', 'maxekg_ecg', 
             'maxencount_enum', 'maxencounter_masterdata', 'maxend_of_life', 
             'maxeosinophils', 'maxesr', 'maxeverwardorICU', 'maxeverwardorICU_p1', 
             'maxexpired', 'maxexpired_p1', 'maxfio2', 'maxfio2_final', 'maxfio2_final2', 
             'maxfio2_final3', 'maxfio2_final3_sofa', 'maxfio2_final_p1', 'maxfio2_finaltest', 
             'maxfio2_p1', 'maxfio2_vent', 'maxfirst_abx_day', 'maxfirst_abx_flag', 
             'maxfirst_abx_iv', 'maxfirst_abx_range', 'maxfirst_vitals_time', 'maxfungal_ad', 
             'maxgastric_output', 'maxgcs_eye', 'maxgcs_motor', 'maxgcs_score', 
             'maxgcs_score_sofa', 'maxgcs_verbal', 'maxhb1198', 'maxhb1200', 'maxhc03', 
             'maxhc03_ven', 'maxhco3_art', 'maxheadneck_w_ct', 'maxheadneck_wo_ct', 
             'maxhematocrit', 'maxhfnc', 'maxhfo_fio2', 'maxhr_c', 'maxhypogly_ad', 
             'maxhypoglycemic_ins', 'maxicd9_477_x', 'maxicd9_493_x', 'maxicd9_558_3', 
             'maxicd9_691_x', 'maxicd9_995_3', 'maxicu_flag', 'maxicu_flag_p1', 'maximmuno_ad', 
             'maximmuno_flag', 'maxinfxnqsofa', 'maxinotrope', 'maxinr', 'maxirb_drug', 
             'maxivbolus', 'maxivbolus_alb', 'maxivbolus_lr', 'maxivbolus_nacl', 'maxivbolus_p1', 
             'maxketones', 'maxlactate', 'maxlactate1_p1', 'maxlactate_wholebld1434', 
             'maxlactate_wholebld4303', 'maxlactic_acid', 
             'maxlactulose', 'maxlast_vitals_time', 'maxlipase', 'maxlos', 'maxlos_total', 'maxlvad', 
             'maxlymphocytes', 'maxmagnesium', 'maxmap_notcalc', 'maxmap_zzz', 'maxmcv', 
             'maxmech_ventil', 'maxmetamyelocytes', 'maxmonocytes', 'maxmorse_ambaid', 
             'maxmorse_dateoffall', 'maxmorse_fallhistory', 'maxmorse_gaittransfer', 
             'maxmorse_ivdevice', 'maxmorse_mentalstatus', 'maxmorse_score', 'maxmorse_secdiag', 
             'maxnasal_cannula', 'maxnebtrt', 'maxneutrophils', 'maxni_fio2', 'maxni_vent', 
             'maxnrbc', 'maxnum_icustays', 'maxnum_icustays_p1', 'maxo2_device', 'maxo2_flow', 
             'maxone_day_before_prior', 'maxosmolality', 'maxother_o2device', 'maxpaco2', 
             'maxpain_scale', 'maxpao2', 'maxpao2_sofa', 'maxpco2_1097', 'maxpco2_4098', 
             'maxperitoneal', 'maxph1250', 'maxph1819', 'maxph272', 'maxph4315', 'maxph690', 
             'maxphosphate', 'maxpotassium_c', 'maxprior_abx_day', 'maxpromyelocytes', 
             'maxptt', 'maxpvco2', 'maxpvo2', 'maxrass', 'maxrbc', 'maxrdw', 'maxroomair', 
             'maxrosc', 'maxrrt', 'maxruq_ultrasound01', 'maxseason_x', 'maxseason1_x', 
             'maxseason_p1_x', 'maxsedative_icu', 'maxsepsis_antibiotic', 'maxsepsis_glucocorticoid', 
             'maxsf_ratio', 'maxsf_ratio_old', 'maxsf_ratio_p1', 'maxsitter_order', 'maxsofa', 
             'maxsofa_bili', 'maxsofa_card', 'maxsofa_coag', 'maxsofa_cr', 'maxsofa_gcs', 
             'maxsofa_resp', 'maxsofa_score', 'maxstaph', 'maxsteroid_ad', 'maxsuction_1hour_trigger', 
             'maxsuction_route2_nur', 'maxsuction_route_rt', 'maxsuction_zzz', 'maxsvo2_2641', 
             'maxsvo2_4351', 'maxtemp_c', 'maxtemp_c_ecart', 'maxtemp_c_p1', 'maxtotal_protein', 
             'maxtrach', 'maxtranscryo', 'maxtransfer_order', 'maxtransfer_order_p1', 'maxtransffp', 
             'maxtransplts', 'maxtransrbc', 'maxtransrbc_eq1_p1', 'maxtransrbc_gt1_p1', 
             'maxtreatment_limit', 'maxtreatment_limit_p1', 'maxtroponin', 'maxtroponin_bin', 
             'maxtroponin_flag', 'maxtroponin_old', 'maxtroponin_p1', 'maxtube_output', 
             'maxtwo_days_before_prior', 'maxurin_cath', 'maxurin_output', 'maxvasoactive', 
             'maxvitals_time', 'maxwardorICU', 'maxwardorICU_p1', 'maxwound_output', 
             'min(day_to_read)', 'min(days_prior)', 'minabs_bands', 'minalbumin_c', 
             'minalt', 'minauto_abs_neutrophils', 'minbands', 'minbasophils', 'minblasts', 
             'minbraden_activity', 'minbraden_friction', 'minbraden_mobility', 'minbraden_moisture', 
             'minbraden_nutrition', 'minbraden_sensory', 'mincdiff', 'minchloride', 'mincortisol', 
             'mincrp', 'mindatamorse_secdiag', 'minday', 'minfirst_vitals_time', 'mingastric_output', 
             'mingcs_eye', 'mingcs_motor', 'mingcs_score_sofa', 'mingcs_verbal', 'minheadneck_w_ct', 
             'minheadneck_wo_ct', 'minhematocrit', 'minketones', 'minlactic_acid', 'minlast_vitals_time', 
             'minlipase', 'minlymphocytes', 'minmagnesium', 'minmap_notcalc', 'minmap_zzz', 'minmetamyelocytes', 
             'minmonocytes', 'minmorse_ambaid', 'minmorse_dateoffall', 'minmorse_fallhistory', 
             'minmorse_gaittransfer', 'minmorse_ivdevice', 'minmorse_mentalstatus', 'minneutrophils', 
             'mino2_flow', 'minosmolality', 'minphosphate', 'minplatelet_count_c', 'minptt', 'minpvco2', 
             'minpvo2', 'minrass', 'minrbc', 'minrdw', 'minseason_x', 'minseason1_x', 'minseason_p1_x', 
             'minsofa_bili', 'minsofa_card', 'minsofa_coag', 'minsofa_cr', 'minsofa_gcs', 'minsofa_resp', 
             'mintemp_c', 'mintemp_c_ecart', 'mintemp_c_p1', 'minvitals_time', 'minwbc_c', 'patient_id_sep', 
             'patient_id_x', 'patient_id_y', 'read_enc', 'septic_enc', 'sumcdiff', 'sumchest_xray', 
             'sumchestab_w_ct', 'sumchestab_wo_ct', 'sumekg_ecg', 'sumelix_comorb', 'sumfio2_final3_sofa', 
             'summob_lo', 'sumother_o2device', 'sumpao2_sofa', 'sumtroponin', 'category_sex', 'race_white', 
             'race_black/african-american', 'race_asian/mideast indian', 
             'race_native hawaiian/other pacific islander', 'race_more than one race', 'category_route', 
             'category_ethnicity', 'discharge - snf', 'discharge - home lw', 'location_ward', 'location_er', 
             'location_icu', 'location_invt', 'location_or', 'TS605', 'pat_enc', 'antiarrhythmic', 'antibiotic', 
             'anticoagulant', 'anticonvulsant', 'antidiabetic', 'antifungal', 'antihypertensive', 'antipsychotic', 
             'antiviral', 'cancerdrug', 'diuretic', 'hormone', 'immunosuppresive', 'corticolsteroid', 'narcotic', 
             'other', 'sedative', 'steroid', 'min_rheetime', 'max_rheetime', 'min_firstrheetime', 
             'max_firstrheetime', 'min_rhee', 'max_rhee', 'avg_rhee', 'min_antibiotic', 'max_antibiotic', 
             'avg_antibiotic', 'min_los_total', 'los_by_day', 'los_5day', 'los_10day', 'los_15day', 'los_b7day', 
             'los_b14day', 'patient_id', 'encounter_id_y', 'minmonth', 'maxmonth', 'minseason_y', 'maxseason_y', 
             'minseason_p1_y', 'maxseason_p1_y', 'maxmonth_p1', 'minseason1_y', 'maxseason1_y', 'maxmonth1', 
             'los_hr', 'countloc_cat', 'protein_oor', 'avgmeds_per_day', 'sofa_taken', 'logsum_elix_comorb']
df = df[no_p1]

# %%
df_rm_death = df[df['maxdied_ever']!= 1]
#df_los_90_o = df_rm_death[df_rm_death['los_hr']<= 90]
#df_los_90 = df_los_90_o.drop(['encounter_id_y','day_to_read','loc_cat','patient_id','encounter_id_x','minseason_x','maxseason_x','maxseason_p1_x','minseason_p1_x','maxseason1_x','minseason1_x','maxday','patient_id_x','patient_id_sep','pat_enc','maxday_y','min(day_to_read)','septic_enc','read_enc','2','minday','1m_read','1y_6m_noread','1y_noread','2m_read','2y_noread','3m_read','6m_noread','patient_id_y'], axis=1)
#df_los_60_o = df_rm_death[df_rm_death['los_hr']<= 60]
#df__los_60 = df_los_60_o.drop(['encounter_id_y','day_to_read','loc_cat','patient_id','encounter_id_x','minseason_x','maxseason_x','maxseason_p1_x','minseason_p1_x','maxseason1_x','minseason1_x','maxday','patient_id_x','patient_id_sep','pat_enc','maxday_y','min(day_to_read)','septic_enc','read_enc','2','minday','1m_read','1y_6m_noread','1y_noread','2m_read','2y_noread','3m_read','6m_noread','patient_id_y'], axis=1)
df_los_30_o = df_rm_death[df_rm_death['los_hr']<= 30]
df_los_30 = df_los_30_o.drop(['encounter_id_y','day_to_read','loc_cat','patient_id','encounter_id_x','minseason_x','maxseason_x','maxseason_p1_x','minseason_p1_x','maxseason1_x','minseason1_x','maxday','patient_id_x','patient_id_sep','pat_enc','maxday_y','min(day_to_read)','septic_enc','read_enc','2','minday','1m_read','1y_6m_noread','1y_noread','2m_read','2y_noread','3m_read','6m_noread','patient_id_y'], axis=1)
#df_no_p1_los_60n = df_los_60.drop(['maxseason1_y','minseason1_y'], axis=1)
df_no_p1_los_30n = df_los_30.drop(['maxseason1_y','minseason1_y'], axis=1)

#d1m6 = df_no_p1_los_60n
#d1m6 = d1m6.fillna(0)
#d1m6 = d1m6.iloc[0:]
#d1mtarget6 = df_los_60_o['1m_read'].iloc[0:]#still df because rows have not changed
#d1mtarget6 = d1mtarget6.astype(np.float64)
#d1mtarget6 = d1mtarget6.fillna(0)
#ft_nm_d1m6 = list(df_no_p1_los_60n.columns)
d1m3 = df_no_p1_los_30n
d1m3 = d1m3.fillna(0)
#d1m3 = d1m3.iloc[0:]
d1mtarget3 = df_los_30_o['1m_read'].iloc[0:]#still df because rows have not changed
d1mtarget3 = d1mtarget3.astype(np.float64)
d1mtarget3 = d1mtarget3.fillna(0)
ft_nm_d1m3 = list(df_no_p1_los_30n.columns)
#drd6 = df_no_p1_los_60n #ADD 1m,2m,3m
#drd6 = drd6.fillna(0)
#drd6 = drd6.iloc[0:]
#drdtarget6 = df_los_60_o['day_to_read'].iloc[0:] #still df because rows have not changed
#drdtarget6 = drdtarget6.astype(np.float64)
#drdtarget6 = drdtarget6.fillna(0)
#ft_nm_drd6 = list(df_no_p1_los_60n.columns)
drd3 = df_no_p1_los_30n #ADD 1m,2m,3m
drd3 = drd3.fillna(0)
#drd3 = drd3.iloc[0:]
drdtarget3 = df_los_30_o['day_to_read'].iloc[0:] #still df because rows have not changed
drdtarget3 = drdtarget3.astype(np.float64)
drdtarget3 = drdtarget3.fillna(0)
ft_nm_drd3 = list(df_no_p1_los_30n.columns)

# %%
#MAKESHIFT LIST
magic = ['avgIVF_volume', 
         'avgabs_bands', 
         'avgabs_neutrophils', 
         'avgalbumin_c', 
         'avgallphos_c', 
         'avgalt', 
         'avgammonia', 
         'avgantitrypsin', 
         'avgavpu_c', 
         'avgbands', 
         'avgbasophils', 
         'avgblasts', 
         'avgbmi', 
         'avgbraden_scale', 
         'avgbun_c', 
         'avgbun_cr_c', 
         'avgcalcium_c', 'avgchloride', 'avgco2_c', 
         'avgcortisol', 'avgcreatinine_c', 'avgcrp', 
         'avgdbp_c', 'avgdrip_dexmedetomidine', 
         'avgdrip_dobutamine', 'avgdrip_dopamine', 
         'avgdrip_fentanyl', 'avgdrip_midazolam', 
         'avgdrip_milrinone', 'avgdrip_morphine', 
         'avgdrip_norepinephrine', 'avgdrip_phenylephrine', 
         'avgdrip_propofol', 'avgdrip_vasopressin', 
         'avgecart_score', 'avgelix_comorb', 'avgencount_enum', 
         'avgeosinophils', 'avgesr', 'avgfio2', 'avgfio2_vent', 
         'avggastric_output', 'avggcs_score', 'avggluc_ser_c', 
         'avghb1198', 'avghb1200', 'avghb_c', 'avghc03_ven', 
         'avgheadneck_w_ct', 'avgheadneck_wo_ct', 'avghematocrit', 
         'avghfo_fio2', 'avghr_c', 'avginr', 'avgketones', 
         'avglactate', 'avglactate1_p1', 'avglactate_wholebld1434', 
         'avglactate_wholebld4303', 'avglactic_acid', 'avglipase_p1', 
         'avglos', 'avglos_total', 'avglymphocytes', 'avgmagnesium', 
         'avgmap_notcalc', 'avgmap_zzz', 'avgmcv', 'avgmetamyelocytes', 
         'avgmonocytes', 'avgmorse_score', 'avgneutrophils', 'avgni_fio2', 
         'avgnrbc', 'avgo2_flow', 'avgo2sat_c', 'avgosmolality', 'avgpaco2', 
         'avgpain_scale', 'avgpao2', 'avgph1250', 'avgph1819', 'avgph272', 
         'avgph4315', 'avgph690', 'avgphosphate', 'avgplatelet_count_c', 
         'avgpotassium_c', 'avgppi_c', 'avgpromyelocytes', 'avgptt', 
         'avgrass', 'avgrbc', 'avgrdw', 'avgrr_c', 'avgsbp_c', 
         'avgsf_ratio', 'avgsf_ratio_old', 'avgsf_ratio_p1', 
         'avgsgot_c', 'avgsodium_c', 'avgsofa_score', 'avgsvo2_2641', 
         'avgsvo2_4351', 'avgtemp_c', 'avgtemp_c_ecart', 'avgtemp_c_p1', 
         'avgtotal_protein', 'avgtroponin_bin', 'avgtroponin_old', 
         'avgtube_output', 'avgwbc_c', 'avgwound_output', 'countIVF_meds', 
         'countabdominal_assess', 'countcart', 'countcart_loc', 'countcart_p1', 
         'countcentral_line', 'countenc_eio', 'countmed_name', 'countroute', 
         'days_prior', 'diffbmi', 'encounter_id_p1', 'hr_c', 'lipase', 
         'maxIVF_meds', 'maxIVF_volume', 'maxIV_intake', 'maxabs_bands', 
         'maxabs_neutrophil_p1', 'maxabs_neutrophils', 
         'maxabx_cont_washout', 'maxabx_day_flag', 'maxabx_flag', 
         'maxabx_sum_1day', 'maxabx_sum_2day', 'maxabx_sum_3day', 
         'maxabx_sum_4day', 'maxabx_washout', 'maxadmission_order', 
         'maxadmission_order_p1', 'maxaed_med', 'maxage', 'maxage_p1', 
         'maxalt', 'maxantiarrhythmic_ad', 'maxanticoag_ad', 'maxantipsych_ad', 
         'maxantitrypsin', 'maxantiviral_ad', 'maxauto_abs_neutrophils', 'maxavnodal_ad', 
         'maxbands', 'maxbasophils', 'maxbenzo_diaz', 'maxbipap', 'maxblasts', 
         'maxbraden_activity', 'maxbraden_friction', 'maxbraden_mobility', 
         'maxbraden_moisture', 'maxbraden_nutrition', 'maxbraden_scale', 
         'maxbraden_sensory', 'maxcardiac_rhythm', 'maxcdiff', 'maxchloride', 
         'maxcontam_true', 'maxcortisol', 'maxcpap', 'maxcrp', 'maxct_chestabdpelviswo', 
         'maxct_chesupabd', 'maxct_lowextrem_w', 'maxct_lowextrem_wo', 'maxct_w_contrast', 
         'maxct_wo_contrast', 'maxcul_blood_ord', 'maxcul_cathtip', 'maxcul_csf', 
         'maxcul_influenza', 'maxcul_mrsa', 'maxcul_other_ord', 'maxcul_parainfluenza', 
         'maxcul_resp', 'maxcul_stool_ord', 'maxcul_urine_ord', 'maxculblood_range', 
         'maxday_p1', 'maxdialysis', 'maxdied01_p1', 'maxdied_ever', 'maxdied_ever_p1', 
         'maxdiuretic_ad', 'maxdrip_dexmedetomidine', 'maxdrip_dobutamine', 
         'maxdrip_dopamine', 'maxdrip_fentanyl', 'maxdrip_midazolam', 
         'maxdrip_milrinone', 'maxdrip_morphine', 'maxdrip_norepinephrine', 
         'maxdrip_phenylephrine', 'maxdrip_propofol', 'maxdrip_vasopressin', 
         'maxecart_score', 'maxekg_ecg', 'maxencount_enum', 
         'maxencounter_masterdata', 'maxend_of_life', 'maxeosinophils', 
         'maxesr', 'maxeverwardorICU', 'maxeverwardorICU_p1', 'maxexpired', 
         'maxexpired_p1', 'maxfio2', 'maxfio2_final', 'maxfio2_final2', 'maxfio2_final3', 
         'maxfio2_final3_sofa', 'maxfio2_final_p1', 'maxfio2_finaltest', 'maxfio2_p1', 
         'maxfio2_vent', 'maxfirst_abx_day', 'maxfirst_abx_flag', 'maxfirst_abx_iv', 
         'maxfirst_abx_range', 'maxfirst_vitals_time', 'maxfungal_ad', 'maxgastric_output', 
         'maxgcs_eye', 'maxgcs_motor', 'maxgcs_score', 'maxgcs_score_sofa', 'maxgcs_verbal', 
         'maxhb1198', 'maxhb1200', 'maxhc03', 'maxhc03_ven', 'maxhco3_art', 'maxheadneck_w_ct', 
         'maxheadneck_wo_ct', 'maxhematocrit', 'maxhfnc', 'maxhfo_fio2', 'maxhr_c', 'maxhypogly_ad', 
         'maxhypoglycemic_ins', 'maxicd9_477_x', 'maxicd9_493_x', 'maxicd9_558_3', 'maxicd9_691_x', 
         'maxicd9_995_3', 'maxicu_flag', 'maxicu_flag_p1', 'maximmuno_ad', 'maximmuno_flag', 
         'maxinfxnqsofa', 'maxinotrope', 'maxinr', 'maxirb_drug', 'maxivbolus', 'maxivbolus_alb', 
         'maxivbolus_lr', 'maxivbolus_nacl', 'maxivbolus_p1', 'maxketones', 'maxlactate', 'maxlactate1_p1', 
         'maxlactate_wholebld1434', 'maxlactate_wholebld4303', 'maxlactic_acid', 'maxlactulose', 
         'maxlast_vitals_time', 'maxlipase', 'maxlos', 'maxlos_total', 'maxlvad', 'maxlymphocytes', 
         'maxmagnesium', 'maxmap_notcalc', 'maxmap_zzz', 'maxmcv', 'maxmech_ventil', 
         'maxmetamyelocytes', 'maxmonocytes', 'maxmorse_ambaid', 'maxmorse_dateoffall', 
         'maxmorse_fallhistory', 'maxmorse_gaittransfer', 'maxmorse_ivdevice', 
         'maxmorse_mentalstatus', 'maxmorse_score', 'maxmorse_secdiag', 'maxnasal_cannula', 
         'maxnebtrt', 'maxneutrophils', 'maxni_fio2', 'maxni_vent', 'maxnrbc', 'maxnum_icustays', 
         'maxnum_icustays_p1', 'maxo2_device', 'maxo2_flow', 'maxone_day_before_prior', 'maxosmolality',
         'maxother_o2device', 'maxpaco2', 'maxpain_scale', 'maxpao2', 
         'maxpao2_sofa', 'maxpco2_1097', 'maxpco2_4098', 'maxperitoneal', 'maxph1250', 
         'maxph1819', 'maxph272', 'maxph4315', 'maxph690', 'maxphosphate', 'maxpotassium_c', 
         'maxprior_abx_day', 'maxpromyelocytes', 'maxptt', 'maxpvco2', 'maxpvo2', 'maxrass', 'maxrbc', 
         'maxrdw', 'maxroomair', 'maxrosc', 'maxrrt', 'maxruq_ultrasound01', 'maxsedative_icu', 
         'maxsepsis_antibiotic', 'maxsepsis_glucocorticoid', 'maxsf_ratio', 'maxsf_ratio_old', 
         'maxsf_ratio_p1', 'maxsitter_order', 'maxsofa', 'maxsofa_bili', 'maxsofa_card', 
         'maxsofa_coag', 'maxsofa_cr', 'maxsofa_gcs', 'maxsofa_resp', 'maxsofa_score', 'maxstaph', 
         'maxsteroid_ad', 'maxsuction_1hour_trigger', 'maxsuction_route2_nur', 'maxsuction_route_rt', 
         'maxsuction_zzz', 'maxsvo2_2641', 'maxsvo2_4351', 'maxtemp_c', 'maxtemp_c_ecart', 
         'maxtemp_c_p1', 'maxtotal_protein', 'maxtrach', 'maxtranscryo', 'maxtransfer_order', 
         'maxtransfer_order_p1', 'maxtransffp', 'maxtransplts', 'maxtransrbc', 
         'maxtransrbc_eq1_p1', 'maxtransrbc_gt1_p1', 'maxtreatment_limit', 
         'maxtreatment_limit_p1', 'maxtroponin', 'maxtroponin_bin', 
         'maxtroponin_flag', 'maxtroponin_old', 'maxtroponin_p1', 
         'maxtube_output', 'maxtwo_days_before_prior', 'maxurin_cath', 
         'maxurin_output', 'maxvasoactive', 'maxvitals_time', 'maxwardorICU', 'maxwardorICU_p1', 
         'maxwound_output', 'min(days_prior)', 'minabs_bands', 'minalbumin_c', 'minalt', 
         'minauto_abs_neutrophils', 'minbands', 'minbasophils', 'minblasts', 'minbraden_activity', 
         'minbraden_friction', 'minbraden_mobility', 'minbraden_moisture', 'minbraden_nutrition', 
         'minbraden_sensory', 'mincdiff', 'minchloride', 'mincortisol', 'mincrp', 'mindatamorse_secdiag', 
         'minfirst_vitals_time', 'mingastric_output', 'mingcs_eye', 'mingcs_motor', 
         'mingcs_score_sofa', 'mingcs_verbal', 'minheadneck_w_ct', 'minheadneck_wo_ct', 
         'minhematocrit', 'minketones', 'minlactic_acid', 'minlast_vitals_time', 'minlipase', 
         'minlymphocytes', 'minmagnesium', 'minmap_notcalc', 'minmap_zzz', 'minmetamyelocytes', 
         'minmonocytes', 'minmorse_ambaid', 'minmorse_dateoffall', 'minmorse_fallhistory', 
         'minmorse_gaittransfer', 'minmorse_ivdevice', 'minmorse_mentalstatus', 'minneutrophils', 
         'mino2_flow', 'minosmolality', 'minphosphate', 'minplatelet_count_c', 'minptt', 'minpvco2', 
         'minpvo2', 'minrass', 'minrbc', 'minrdw', 'minsofa_bili', 'minsofa_card', 'minsofa_coag', 
         'minsofa_cr', 'minsofa_gcs', 'minsofa_resp', 'mintemp_c', 'mintemp_c_ecart', 
         'mintemp_c_p1', 'minvitals_time', 'minwbc_c', 'sumcdiff', 'sumchest_xray', 
         'sumchestab_w_ct', 'sumchestab_wo_ct', 'sumekg_ecg', 'sumelix_comorb', 
         'sumfio2_final3_sofa', 'summob_lo', 'sumother_o2device', 'sumpao2_sofa', 
         'sumtroponin', 'category_sex', 'race_white', 'race_black/african-american', 
         'race_asian/mideast indian', 'race_native hawaiian/other pacific islander', 
         'race_more than one race', 'category_route', 'category_ethnicity', 
         'discharge - snf', 'discharge - home lw', 
         'location_ward', 'location_er', 'location_icu', 'location_invt', 'location_or', 
         'TS605', 'antiarrhythmic', 'antibiotic', 'anticoagulant', 'anticonvulsant', 'antidiabetic', 
         'antifungal', 'antihypertensive', 'antipsychotic', 'antiviral', 'cancerdrug', 
         'diuretic', 'hormone', 'immunosuppresive', 'corticolsteroid', 'narcotic', 'other', 
         'sedative', 'steroid', 'min_rheetime', 'max_rheetime', 'min_firstrheetime', 
         'max_firstrheetime', 'min_rhee', 'max_rhee', 'avg_rhee', 'min_antibiotic', 
         'max_antibiotic', 'avg_antibiotic', 'min_los_total', 'los_by_day', 
         'los_5day', 'los_10day', 'los_15day', 'los_b7day', 'los_b14day', 'minmonth', 
         'maxmonth', 'minseason_y', 'maxseason_y', 'minseason_p1_y', 'maxseason_p1_y', 
         'maxmonth_p1', 'maxmonth1', 'los_hr', 'countloc_cat', 'protein_oor', 
         'avgmeds_per_day', 'sofa_taken', 'logsum_elix_comorb']

#NEXT ITERATION REMOVE ALL P1, leave in month and season to show had visit
magic_nop1 = ['avgIVF_volume',
              'avgabs_bands', 
              'avgabs_neutrophils', 
              'avgalbumin_c', 
              'avgallphos_c', 
              'avgalt', 
              'avgammonia', 
              'avgantitrypsin', 
              'avgavpu_c', 
              'avgbands', 
              'avgbasophils', 
              'avgblasts', 
              'avgbmi', 
              'avgbraden_scale', 
              'avgbun_c',
              'avgbun_cr_c', 
              'avgcalcium_c', 
              'avgchloride', 
              'avgco2_c', 
              'avgcortisol', 
              'avgcreatinine_c', 
              'avgcrp', 
              'avgdbp_c', 
              'avgdrip_dexmedetomidine', 
              'avgdrip_dobutamine', 
              'avgdrip_dopamine', 
              'avgdrip_fentanyl', 
              'avgdrip_midazolam', 
              'avgdrip_milrinone', 
              'avgdrip_morphine', 
              'avgdrip_norepinephrine', 
              'avgdrip_phenylephrine', 
              'avgdrip_propofol', 
              'avgdrip_vasopressin',
              'avgecart_score', 
              'avgelix_comorb', 
              'avgencount_enum', 
              'avgeosinophils', 
              'avgesr', 
              'avgfio2', 
              'avgfio2_vent', 
              'avggastric_output', 
              'avggcs_score', 
              'avggluc_ser_c', 
              'avghb1198', 
              'avghb1200', 
              'avghb_c', 
              'avghc03_ven', 
              'avgheadneck_w_ct', 
              'avgheadneck_wo_ct', 
              'avghematocrit', 
              'avghfo_fio2', 
              'avghr_c', 
              'avginr', 
              'avgketones', 
              'avglactate', 
              'avglactate_wholebld1434', 
              'avglactate_wholebld4303', 
              'avglactic_acid',  
              'avglos', 
              'avglos_total', 
              'avglymphocytes', 
              'avgmagnesium', 
              'avgmap_notcalc', 
              'avgmap_zzz', 
              'avgmcv', 
              'avgmetamyelocytes', 
              'avgmonocytes', 
              'avgmorse_score', 
              'avgneutrophils', 
              'avgni_fio2', 
              'avgnrbc', 
              'avgo2_flow', 
              'avgo2sat_c', 
              'avgosmolality', 
              'avgpaco2', 
              'avgpain_scale', 
              'avgpao2', 
              'avgph1250', 
              'avgph1819', 
              'avgph272', 
              'avgph4315', 
              'avgph690', 
              'avgphosphate', 
              'avgplatelet_count_c', 
              'avgpotassium_c', 
              'avgppi_c', 
              'avgpromyelocytes', 
              'avgptt', 
              'avgrass', 
              'avgrbc', 
              'avgrdw', 
              'avgrr_c', 
              'avgsbp_c', 
              'avgsf_ratio', 
              'avgsf_ratio_old', 
              'avgsf_ratio_p1', 
              'avgsgot_c', 
              'avgsodium_c', 
              'avgsofa_score', 
              'avgsvo2_2641', 
              'avgsvo2_4351', 
              'avgtemp_c', 
              'avgtemp_c_ecart', 
              'avgtotal_protein', 
              'avgtroponin_bin', 
              'avgtroponin_old', 
              'avgtube_output', 
              'avgwbc_c', 
              'avgwound_output', 
              'countIVF_meds', 
              'countabdominal_assess', 
              'countcart', 
              'countcart_loc', 
              'countcentral_line', 
              'countenc_eio', 
              'countmed_name', 
              'countroute', 
              'days_prior', 
              'diffbmi', 
              'hr_c', 
              'lipase', 
              'maxIVF_meds', 
              'maxIVF_volume', 
              'maxIV_intake', 
              'maxabs_bands', 
              'maxabs_neutrophil_p1', 
              'maxabs_neutrophils', 
              'maxabx_cont_washout', 
              'maxabx_day_flag', 
              'maxabx_flag', 
              'maxabx_sum_1day', 
              'maxabx_sum_2day', 
              'maxabx_sum_3day', 
              'maxabx_sum_4day', 
              'maxabx_washout', 
              'maxadmission_order', 
              'maxadmission_order_p1', 
              'maxaed_med', 
              'maxage', 
              'maxage_p1', 
              'maxalt', 
              'maxantiarrhythmic_ad', 
              'maxanticoag_ad', 
              'maxantipsych_ad', 
              'maxantitrypsin', 
              'maxantiviral_ad', 
              'maxauto_abs_neutrophils', 
              'maxavnodal_ad', 
              'maxbands', 
              'maxbasophils', 
              'maxbenzo_diaz', 
              'maxbipap', 
              'maxblasts', 
              'maxbraden_activity', 
              'maxbraden_friction', 
              'maxbraden_mobility', 
              'maxbraden_moisture', 
              'maxbraden_nutrition', 
              'maxbraden_scale', 
              'maxbraden_sensory', 
              'maxcardiac_rhythm', 
              'maxcdiff', 
              'maxchloride', 
              'maxcontam_true', 
              'maxcortisol', 
              'maxcpap', 
              'maxcrp', 
              'maxct_chestabdpelviswo', 
              'maxct_chesupabd', 
              'maxct_lowextrem_w', 
              'maxct_lowextrem_wo', 
              'maxct_w_contrast', 
              'maxct_wo_contrast', 
              'maxcul_blood_ord', 
              'maxcul_cathtip', 
              'maxcul_csf', 
              'maxcul_influenza', 
              'maxcul_mrsa', 
              'maxcul_other_ord', 
              'maxcul_parainfluenza', 
              'maxcul_resp', 
              'maxcul_stool_ord', 
              'maxcul_urine_ord', 
              'maxculblood_range', 
              'maxdialysis', 
              'maxdied_ever', 
              'maxdiuretic_ad', 
              'maxdrip_dexmedetomidine', 
              'maxdrip_dobutamine', 
              'maxdrip_dopamine', 
              'maxdrip_fentanyl', 
              'maxdrip_midazolam', 
              'maxdrip_milrinone', 
              'maxdrip_morphine', 
              'maxdrip_norepinephrine',
              'maxdrip_phenylephrine', 
              'maxdrip_propofol', 
              'maxdrip_vasopressin', 
              'maxecart_score', 
              'maxekg_ecg', 
              'maxencount_enum', 
              'maxencounter_masterdata', 
              'maxend_of_life', 
              'maxeosinophils', 
              'maxesr', 
              'maxeverwardorICU', 
              'maxexpired', 
              'maxfio2', 
              'maxfio2_final', 
              'maxfio2_final2', 
              'maxfio2_final3', 
              'maxfio2_final3_sofa',  
              'maxfio2_finaltest', 
              'maxfio2_vent', 
              'maxfirst_abx_day', 
              'maxfirst_abx_flag', 
              'maxfirst_abx_iv', 
              'maxfirst_abx_range', 
              'maxfirst_vitals_time', 
              'maxfungal_ad', 
              'maxgastric_output', 
              'maxgcs_eye', 
              'maxgcs_motor', 
              'maxgcs_score', 
              'maxgcs_score_sofa', 
              'maxgcs_verbal', 
              'maxhb1198', 
              'maxhb1200', 
              'maxhc03', 
              'maxhc03_ven', 
              'maxhco3_art', 
              'maxheadneck_w_ct', 
              'maxheadneck_wo_ct', 
              'maxhematocrit', 
              'maxhfnc', 
              'maxhfo_fio2', 
              'maxhr_c', 
              'maxhypogly_ad', 
              'maxhypoglycemic_ins', 
              'maxicd9_477_x', 
              'maxicd9_493_x', 
              'maxicd9_558_3', 
              'maxicd9_691_x', 
              'maxicd9_995_3', 
              'maxicu_flag', 
              'maximmuno_ad', 
              'maximmuno_flag', 
              'maxinfxnqsofa', 
              'maxinotrope', 
              'maxinr', 
              'maxirb_drug', 
              'maxivbolus', 
              'maxivbolus_alb', 
              'maxivbolus_lr', 
              'maxivbolus_nacl', 
              'maxketones', 
              'maxlactate', 
              'maxlactate_wholebld1434', 
              'maxlactate_wholebld4303', 
              'maxlactic_acid', 
              'maxlactulose', 
              'maxlast_vitals_time', 
              'maxlipase', 
              'maxlos', 
              'maxlos_total', 
              'maxlvad', 
              'maxlymphocytes', 
              'maxmagnesium', 
              'maxmap_notcalc', 
              'maxmap_zzz', 
              'maxmcv', 
              'maxmech_ventil', 
              'maxmetamyelocytes', 
              'maxmonocytes', 
              'maxmorse_ambaid', 
              'maxmorse_dateoffall', 
              'maxmorse_fallhistory', 
              'maxmorse_gaittransfer', 
              'maxmorse_ivdevice', 
              'maxmorse_mentalstatus', 
              'maxmorse_score', 
              'maxmorse_secdiag', 
              'maxnasal_cannula', 
              'maxnebtrt', 
              'maxneutrophils', 
              'maxni_fio2', 
              'maxni_vent', 
              'maxnrbc', 
              'maxnum_icustays', 
              'maxnum_icustays_p1', 
              'maxo2_device', 
              'maxo2_flow', 
              'maxone_day_before_prior', 
              'maxosmolality',
              'maxother_o2device', 
              'maxpaco2', 
              'maxpain_scale', 
              'maxpao2',
              'maxpao2_sofa', 
              'maxpco2_1097', 
              'maxpco2_4098', 
              'maxperitoneal', 
              'maxph1250', 
              'maxph1819', 
              'maxph272', 
              'maxph4315', 
              'maxph690', 
              'maxphosphate', 
              'maxpotassium_c', 
              'maxprior_abx_day', 
              'maxpromyelocytes', 
              'maxptt', 
              'maxpvco2', 
              'maxpvo2', 
              'maxrass', 
              'maxrbc',
              'maxrdw', 
              'maxroomair', 
              'maxrosc', 
              'maxrrt', 
              'maxruq_ultrasound01', 
              'maxsedative_icu', 
              'maxsepsis_antibiotic', 
              'maxsepsis_glucocorticoid', 
              'maxsf_ratio', 
              'maxsf_ratio_old', 
              'maxsf_ratio_p1', 
              'maxsitter_order', 
              'maxsofa', 
              'maxsofa_bili', 
              'maxsofa_card', 
              'maxsofa_coag', 
              'maxsofa_cr', 
              'maxsofa_gcs', 
              'maxsofa_resp', 
              'maxsofa_score', 
              'maxstaph',
              'maxsteroid_ad', 
              'maxsuction_1hour_trigger', 
              'maxsuction_route2_nur', 
              'maxsuction_route_rt', 
              'maxsuction_zzz', 
              'maxsvo2_2641', 
              'maxsvo2_4351', 
              'maxtemp_c', 
              'maxtemp_c_ecart', 
              'maxtemp_c_p1', 
              'maxtotal_protein', 
              'maxtrach', 
              'maxtranscryo', 
              'maxtransfer_order', 
              'maxtransffp', 
              'maxtransplts', 
              'maxtransrbc', 
              'maxtreatment_limit',  
              'maxtroponin', 
              'maxtroponin_bin', 
              'maxtroponin_flag', 
              'maxtroponin_old', 
              'maxtube_output', 
              'maxtwo_days_before_prior', 
              'maxurin_cath', 
              'maxurin_output', 
              'maxvasoactive', 
              'maxvitals_time', 
              'maxwardorICU', 
              'maxwound_output', 
              'min(days_prior)', 
              'minabs_bands', 
              'minalbumin_c', 
              'minalt', 
              'minauto_abs_neutrophils', 
              'minbands', 
              'minbasophils', 
              'minblasts', 
              'minbraden_activity', 
              'minbraden_friction', 
              'minbraden_mobility', 
              'minbraden_moisture', 
              'minbraden_nutrition', 
              'minbraden_sensory', 
              'mincdiff', 
              'minchloride', 
              'mincortisol', 
              'mincrp', 
              'mindatamorse_secdiag', 
              'minfirst_vitals_time', 
              'mingastric_output', 
              'mingcs_eye', 
              'mingcs_motor', 
              'mingcs_score_sofa', 
              'mingcs_verbal', 
              'minheadneck_w_ct', 
              'minheadneck_wo_ct', 
              'minhematocrit', 
              'minketones', 
              'minlactic_acid', 
              'minlast_vitals_time', 
              'minlipase', 
              'minlymphocytes', 
              'minmagnesium', 
              'minmap_notcalc', 
              'minmap_zzz', 
              'minmetamyelocytes', 
              'minmonocytes', 
              'minmorse_ambaid', 
              'minmorse_dateoffall', 
              'minmorse_fallhistory', 
              'minmorse_gaittransfer', 
              'minmorse_ivdevice', 
              'minmorse_mentalstatus', 
              'minneutrophils',
              'mino2_flow', 
              'minosmolality', 
              'minphosphate', 
              'minplatelet_count_c', 
              'minptt', 
              'minpvco2', 
              'minpvo2', 
              'minrass', 
              'minrbc', 
              'minrdw', 
              'minsofa_bili', 
              'minsofa_card', 
              'minsofa_coag', 
              'minsofa_cr', 
              'minsofa_gcs', 
              'minsofa_resp', 
              'mintemp_c', 
              'mintemp_c_ecart', 
              'mintemp_c_p1', 
              'minvitals_time', 
              'minwbc_c', 
              'sumcdiff', 
              'sumchest_xray', 
              'sumchestab_w_ct', 
              'sumchestab_wo_ct',
              'sumekg_ecg', 
              'sumelix_comorb', 
              'sumfio2_final3_sofa', 
              'summob_lo', 
              'sumother_o2device', 
              'sumpao2_sofa', 
              'sumtroponin', 
              'category_sex', 
              'race_white', 
              'race_black/african-american', 
              'race_asian/mideast indian', 
              'race_native hawaiian/other pacific islander', 
              'race_more than one race', 
              'category_route', 
              'category_ethnicity', 
              'discharge - snf', 
              'discharge - home lw', 
              'location_ward', 
              'location_er', 
              'location_icu', 
              'location_invt', 
              'location_or', 
              'TS605', 
              'antiarrhythmic', 
              'antibiotic', 
              'anticoagulant', 
              'anticonvulsant', 
              'antidiabetic', 
              'antifungal', 
              'antihypertensive', 
              'antipsychotic', 
              'antiviral', 
              'cancerdrug', 
              'diuretic', 
              'hormone', 
              'immunosuppresive', 
              'corticolsteroid', 
              'narcotic', 
              'other',
              'sedative', 
              'steroid', 
              'min_rheetime', 
              'max_rheetime', 
              'min_firstrheetime', 
              'max_firstrheetime', 
              'min_rhee', 
              'max_rhee', 
              'avg_rhee', 
              'min_antibiotic', 
              'max_antibiotic', 
              'avg_antibiotic', 
              'min_los_total', 
              'los_by_day', 
              'los_5day', 
              'los_10day', 
              'los_15day', 
              'los_b7day', 
              'los_b14day', 
              'minmonth', 
              'maxmonth', 
              'minseason_y', 
              'maxseason_y', 
              'minseason_p1_y', 
              'maxseason_p1_y', 
              'maxmonth_p1', 
              'maxmonth1', 
              'los_hr', 
              'countloc_cat', 
              'protein_oor', 
              'avgmeds_per_day', 
              'sofa_taken', 
              'logsum_elix_comorb']
#NEXT ITERATION SUBTRACT FROM MEAN FOR VITALS and come up with random score for prior visit
#apply to full dataset after complete
list_to_rev_for_threshold_and_outliers = 
              'avgIVF_volume',
              'avgabs_bands', 
              'avgabs_neutrophils', 
              'avgalbumin_c', 
              'avgallphos_c', 
              'avgalt', 
              'avgammonia', 
              'avgantitrypsin', 
              'avgavpu_c', 
              'avgbands', 
              'avgbasophils', 
              'avgblasts', 
              'avgbmi', 
              'avgbraden_scale', 
              'avgbun_c',
              'avgbun_cr_c', 
              'avgcalcium_c', 
              'avgchloride', 
              'avgco2_c', 
              'avgcortisol', 
              'avgcreatinine_c', 
              'avgcrp', 
              'avgdbp_c', 
              'avgdrip_dexmedetomidine', 
              'avgdrip_dobutamine', 
              'avgdrip_dopamine', 
              'avgdrip_fentanyl', 
              'avgdrip_midazolam', 
              'avgdrip_milrinone', 
              'avgdrip_morphine', 
              'avgdrip_norepinephrine', 
              'avgdrip_phenylephrine', 
              'avgdrip_propofol', 
              'avgdrip_vasopressin',
              'avgecart_score', 
              'avgelix_comorb', 
              'avgencount_enum', 
              'avgeosinophils', 
              'avgesr', 
              'avgfio2', 
              'avgfio2_vent', 
              'avggastric_output', 
              'avggcs_score', 
              'avggluc_ser_c', 
              'avghb1198', 
              'avghb1200', 
              'avghb_c', 
              'avghc03_ven', 
              'avgheadneck_w_ct', 
              'avgheadneck_wo_ct', 
              'avghematocrit', 
              'avghfo_fio2', 
              'avghr_c', 
              'avginr', 
              'avgketones', 
              'avglactate', 
              'avglactate_wholebld1434', 
              'avglactate_wholebld4303', 
              'avglactic_acid',  
              'avglos', 
              'avglos_total', 
              'avglymphocytes', 
              'avgmagnesium', 
              'avgmap_notcalc', 
              'avgmap_zzz', 
              'avgmcv', 
              'avgmetamyelocytes', 
              'avgmonocytes', 
              'avgmorse_score', 
              'avgneutrophils', 
              'avgni_fio2', 
              'avgnrbc', 
              'avgo2_flow', 
              'avgo2sat_c', 
              'avgosmolality', 
              'avgpaco2', 
              'avgpain_scale', 
              'avgpao2', 
              'avgph1250', 
              'avgph1819', 
              'avgph272', 
              'avgph4315', 
              'avgph690', 
              'avgphosphate', 
              'avgplatelet_count_c', 
              'avgpotassium_c', 
              'avgppi_c', 
              'avgpromyelocytes', 
              'avgptt', 
              'avgrass', 
              'avgrbc', 
              'avgrdw', 
              'avgrr_c', 
              'avgsbp_c', 
              'avgsf_ratio', 
              'avgsf_ratio_old', 
              'avgsf_ratio_p1', 
              'avgsgot_c', 
              'avgsodium_c', 
              'avgsofa_score', 
              'avgsvo2_2641', 
              'avgsvo2_4351', 
              'avgtemp_c', 
              'avgtemp_c_ecart', 
              'avgtotal_protein', 
              'avgtroponin_bin', 
              'avgtroponin_old', 
              'avgtube_output', 
              'avgwbc_c', 
              'avgwound_output', 
              'countIVF_meds', 
              'countabdominal_assess', 
              'countcart', 
              'countcart_loc', 
              'countcentral_line', 
              'countenc_eio', 
              'countmed_name', 
              'countroute', 
              'days_prior', 
              'diffbmi', 
              'hr_c', 
              'lipase', 
              'maxIVF_meds', 
              'maxIVF_volume', 
              'maxIV_intake', 
              'maxabs_bands', 
              'maxabs_neutrophil_p1', 
              'maxabs_neutrophils', 
              'maxabx_cont_washout', 
              'maxabx_day_flag', 
              'maxabx_flag', 
              'maxabx_sum_1day', 
              'maxabx_sum_2day', 
              'maxabx_sum_3day', 
              'maxabx_sum_4day', 
              'maxabx_washout', 
              'maxadmission_order', 
              'maxadmission_order_p1', 
              'maxaed_med', 
              'maxage', 
              'maxage_p1', 
              'maxalt', 
              'maxantiarrhythmic_ad', 
              'maxanticoag_ad', 
              'maxantipsych_ad', 
              'maxantitrypsin', 
              'maxantiviral_ad', 
              'maxauto_abs_neutrophils', 
              'maxavnodal_ad', 
              'maxbands', 
              'maxbasophils', 
              'maxbenzo_diaz', 
              'maxbipap', 
              'maxblasts', 
              'maxbraden_activity', 
              'maxbraden_friction', 
              'maxbraden_mobility', 
              'maxbraden_moisture', 
              'maxbraden_nutrition', 
              'maxbraden_scale', 
              'maxbraden_sensory', 
              'maxcardiac_rhythm', 
              'maxcdiff', 
              'maxchloride', 
              'maxcontam_true', 
              'maxcortisol', 
              'maxcpap', 
              'maxcrp', 
              'maxct_chestabdpelviswo', 
              'maxct_chesupabd', 
              'maxct_lowextrem_w', 
              'maxct_lowextrem_wo', 
              'maxct_w_contrast', 
              'maxct_wo_contrast', 
              'maxcul_blood_ord', 
              'maxcul_cathtip', 
              'maxcul_csf', 
              'maxcul_influenza', 
              'maxcul_mrsa', 
              'maxcul_other_ord', 
              'maxcul_parainfluenza', 
              'maxcul_resp', 
              'maxcul_stool_ord', 
              'maxcul_urine_ord', 
              'maxculblood_range', 
              'maxdialysis', 
              'maxdied_ever', 
              'maxdiuretic_ad', 
              'maxdrip_dexmedetomidine', 
              'maxdrip_dobutamine', 
              'maxdrip_dopamine', 
              'maxdrip_fentanyl', 
              'maxdrip_midazolam', 
              'maxdrip_milrinone', 
              'maxdrip_morphine', 
              'maxdrip_norepinephrine',
              'maxdrip_phenylephrine', 
              'maxdrip_propofol', 
              'maxdrip_vasopressin', 
              'maxecart_score', 
              'maxekg_ecg', 
              'maxencount_enum', 
              'maxencounter_masterdata', 
              'maxend_of_life', 
              'maxeosinophils', 
              'maxesr', 
              'maxeverwardorICU', 
              'maxexpired', 
              'maxfio2', 
              'maxfio2_final', 
              'maxfio2_final2', 
              'maxfio2_final3', 
              'maxfio2_final3_sofa',  
              'maxfio2_finaltest', 
              'maxfio2_vent', 
              'maxfirst_abx_day', 
              'maxfirst_abx_flag', 
              'maxfirst_abx_iv', 
              'maxfirst_abx_range', 
              'maxfirst_vitals_time', 
              'maxfungal_ad', 
              'maxgastric_output', 
              'maxgcs_eye', 
              'maxgcs_motor', 
              'maxgcs_score', 
              'maxgcs_score_sofa', 
              'maxgcs_verbal', 
              'maxhb1198', 
              'maxhb1200', 
              'maxhc03', 
              'maxhc03_ven', 
              'maxhco3_art', 
              'maxheadneck_w_ct', 
              'maxheadneck_wo_ct', 
              'maxhematocrit', 
              'maxhfnc', 
              'maxhfo_fio2', 
              'maxhr_c', 
              'maxhypogly_ad', 
              'maxhypoglycemic_ins', 
              'maxicd9_477_x', 
              'maxicd9_493_x', 
              'maxicd9_558_3', 
              'maxicd9_691_x', 
              'maxicd9_995_3', 
              'maxicu_flag', 
              'maximmuno_ad', 
              'maximmuno_flag', 
              'maxinfxnqsofa', 
              'maxinotrope', 
              'maxinr', 
              'maxirb_drug', 
              'maxivbolus', 
              'maxivbolus_alb', 
              'maxivbolus_lr', 
              'maxivbolus_nacl', 
              'maxketones', 
              'maxlactate', 
              'maxlactate_wholebld1434', 
              'maxlactate_wholebld4303', 
              'maxlactic_acid', 
              'maxlactulose', 
              'maxlast_vitals_time', 
              'maxlipase', 
              'maxlos', 
              'maxlos_total', 
              'maxlvad', 
              'maxlymphocytes', 
              'maxmagnesium', 
              'maxmap_notcalc', 
              'maxmap_zzz', 
              'maxmcv', 
              'maxmech_ventil', 
              'maxmetamyelocytes', 
              'maxmonocytes', 
              'maxmorse_ambaid', 
              'maxmorse_dateoffall', 
              'maxmorse_fallhistory', 
              'maxmorse_gaittransfer', 
              'maxmorse_ivdevice', 
              'maxmorse_mentalstatus', 
              'maxmorse_score', 
              'maxmorse_secdiag', 
              'maxnasal_cannula', 
              'maxnebtrt', 
              'maxneutrophils', 
              'maxni_fio2', 
              'maxni_vent', 
              'maxnrbc', 
              'maxnum_icustays', 
              'maxnum_icustays_p1', 
              'maxo2_device', 
              'maxo2_flow', 
              'maxone_day_before_prior', 
              'maxosmolality',
              'maxother_o2device', 
              'maxpaco2', 
              'maxpain_scale', 
              'maxpao2',
              'maxpao2_sofa', 
              'maxpco2_1097', 
              'maxpco2_4098', 
              'maxperitoneal', 
              'maxph1250', 
              'maxph1819', 
              'maxph272', 
              'maxph4315', 
              'maxph690', 
              'maxphosphate', 
              'maxpotassium_c', 
              'maxprior_abx_day', 
              'maxpromyelocytes', 
              'maxptt', 
              'maxpvco2', 
              'maxpvo2', 
              'maxrass', 
              'maxrbc',
              'maxrdw', 
              'maxroomair', 
              'maxrosc', 
              'maxrrt', 
              'maxruq_ultrasound01', 
              'maxsedative_icu', 
              'maxsepsis_antibiotic', 
              'maxsepsis_glucocorticoid', 
              'maxsf_ratio', 
              'maxsf_ratio_old', 
              'maxsf_ratio_p1', 
              'maxsitter_order', 
              'maxsofa', 
              'maxsofa_bili', 
              'maxsofa_card', 
              'maxsofa_coag', 
              'maxsofa_cr', 
              'maxsofa_gcs', 
              'maxsofa_resp', 
              'maxsofa_score', 
              'maxstaph',
              'maxsteroid_ad', 
              'maxsuction_1hour_trigger', 
              'maxsuction_route2_nur', 
              'maxsuction_route_rt', 
              'maxsuction_zzz', 
              'maxsvo2_2641', 
              'maxsvo2_4351', 
              'maxtemp_c', 
              'maxtemp_c_ecart', 
              'maxtemp_c_p1', 
              'maxtotal_protein', 
              'maxtrach', 
              'maxtranscryo', 
              'maxtransfer_order', 
              'maxtransffp', 
              'maxtransplts', 
              'maxtransrbc', 
              'maxtreatment_limit',  
              'maxtroponin', 
              'maxtroponin_bin', 
              'maxtroponin_flag', 
              'maxtroponin_old', 
              'maxtube_output', 
              'maxtwo_days_before_prior', 
              'maxurin_cath', 
              'maxurin_output', 
              'maxvasoactive', 
              'maxvitals_time', 
              'maxwardorICU', 
              'maxwound_output', 
              'min(days_prior)', 
              'minabs_bands', 
              'minalbumin_c', 
              'minalt', 
              'minauto_abs_neutrophils', 
              'minbands', 
              'minbasophils', 
              'minblasts', 
              'minbraden_activity', 
              'minbraden_friction', 
              'minbraden_mobility', 
              'minbraden_moisture', 
              'minbraden_nutrition', 
              'minbraden_sensory', 
              'mincdiff', 
              'minchloride', 
              'mincortisol', 
              'mincrp', 
              'mindatamorse_secdiag', 
              'minfirst_vitals_time', 
              'mingastric_output', 
              'mingcs_eye', 
              'mingcs_motor', 
              'mingcs_score_sofa', 
              'mingcs_verbal', 
              'minheadneck_w_ct', 
              'minheadneck_wo_ct', 
              'minhematocrit', 
              'minketones', 
              'minlactic_acid', 
              'minlast_vitals_time', 
              'minlipase', 
              'minlymphocytes', 
              'minmagnesium', 
              'minmap_notcalc', 
              'minmap_zzz', 
              'minmetamyelocytes', 
              'minmonocytes', 
              'minmorse_ambaid', 
              'minmorse_dateoffall', 
              'minmorse_fallhistory', 
              'minmorse_gaittransfer', 
              'minmorse_ivdevice', 
              'minmorse_mentalstatus', 
              'minneutrophils',
              'mino2_flow', 
              'minosmolality', 
              'minphosphate', 
              'minplatelet_count_c', 
              'minptt', 
              'minpvco2', 
              'minpvo2', 
              'minrass', 
              'minrbc', 
              'minrdw', 
              'minsofa_bili', 
              'minsofa_card', 
              'minsofa_coag', 
              'minsofa_cr', 
              'minsofa_gcs', 
              'minsofa_resp', 
              'mintemp_c', 
              'mintemp_c_ecart', 
              'mintemp_c_p1', 
              'minvitals_time', 
              'minwbc_c', 
              'sumcdiff', 
              'sumchest_xray', 
              'sumchestab_w_ct', 
              'sumchestab_wo_ct',
              'sumekg_ecg', 
              'sumelix_comorb', 
              'sumfio2_final3_sofa', 
              'summob_lo', 
              'sumother_o2device', 
              'sumpao2_sofa', 
              'sumtroponin', 
              'category_sex', 
              'race_white', 
              'race_black/african-american', 
              'race_asian/mideast indian', 
              'race_native hawaiian/other pacific islander', 
              'race_more than one race', 
              'category_route', 
              'category_ethnicity', 
              'discharge - snf', 
              'discharge - home lw', 
              'location_ward', 
              'location_er', 
              'location_icu', 
              'location_invt', 
              'location_or', 
              'TS605', 
              'antiarrhythmic', 
              'antibiotic', 
              'anticoagulant', 
              'anticonvulsant', 
              'antidiabetic', 
              'antifungal', 
              'antihypertensive', 
              'antipsychotic', 
              'antiviral', 
              'cancerdrug', 
              'diuretic', 
              'hormone', 
              'immunosuppresive', 
              'corticolsteroid', 
              'narcotic', 
              'other',
              'sedative', 
              'steroid', 
              'min_rheetime', 
              'max_rheetime', 
              'min_firstrheetime', 
              'max_firstrheetime', 
              'min_rhee', 
              'max_rhee', 
              'avg_rhee', 
              'min_antibiotic', 
              'max_antibiotic', 
              'avg_antibiotic', 
              'min_los_total', 
              'los_by_day', 
              'los_5day', 
              'los_10day', 
              'los_15day', 
              'los_b7day', 
              'los_b14day', 
              'minmonth', 
              'maxmonth', 
              'minseason_y', 
              'maxseason_y', 
              'minseason_p1_y', 
              'maxseason_p1_y', 
              'maxmonth_p1', 
              'maxmonth1', 
              'los_hr', 
              'countloc_cat', 
              'protein_oor', 
              'avgmeds_per_day', 
              'sofa_taken', 
              'logsum_elix_comorb']

# %%
len(magic_nop1)

# %%
#d1m6 = df_los_60n[magic]
#d1m6 = d1m6.fillna(0)
#d1m6 = d1m6.iloc[0:]
#d1mtarget6 = df_los_60_o['1m_read'].iloc[0:]#still df because rows have not changed
#d1mtarget6 = d1mtarget6.astype(np.float64)
#d1mtarget6 = d1mtarget6.fillna(0)
#ft_nm_d1m6 = list(df_los_60n.columns)
d1m3 = df_no_p1_los_30n[magic]
d1m3 = d1m3.fillna(0)
#d1m3 = d1m3.iloc[0:]
d1mtarget3 = df_los_30_o['1m_read'].iloc[0:]#still df because rows have not changed
d1mtarget3 = d1mtarget3.astype(np.float64)
d1mtarget3 = d1mtarget3.fillna(0)

d1m3np = df_no_p1_los_30n[magic_nop1]
d1m3np = d1m3np.fillna(0)
#d1m3 = d1m3.iloc[0:]
d1mtarget3np = df_los_30_o['1m_read'].iloc[0:]#still df because rows have not changed
d1mtarget3np = d1mtarget3np.astype(np.float64)
d1mtarget3np = d1mtarget3np.fillna(0)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import AdaBoostClassifier
X = d1m3
y = d1mtarget3

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
clf = AdaBoostClassifier(n_estimators=200, random_state=0)
print(cross_val_score(clf, X, y, cv=skf, n_jobs=1))
# Out:
# [0.88052012 0.87414132 0.87929342 0.87831207 0.86527607 0.88785276
#  0.87092025 0.87484663 0.88392638 0.86254296]

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import AdaBoostClassifier
X = d1m3np
y = d1mtarget3np

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
clf = AdaBoostClassifier(n_estimators=200, random_state=0)
print(cross_val_score(clf, X, y, cv=skf, n_jobs=1))
# Out:
# [0.88052012 0.87536801 0.88002944 0.8765947  0.86969325 0.88539877
#  0.87165644 0.87754601 0.88245399 0.8622975 ]

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
X = d1m3
y = d1mtarget3
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
clf = GradientBoostingClassifier(n_estimators=200, learning_rate=1.0, max_depth=1, random_state=0)
print(cross_val_score(clf, X, y, cv=skf, n_jobs=1))
# Out:
# [0.88150147 0.8734053  0.87684004 0.87365064 0.86871166 0.88368098
#  0.87165644 0.87779141 0.8804908  0.86377025]

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
X = d1m3np
y = d1mtarget3np
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
clf = GradientBoostingClassifier(n_estimators=200, learning_rate=1.0, max_depth=1, random_state=0)
print(cross_val_score(clf, X, y, cv=skf, n_jobs=1))

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier

def extree(features,target,featname):
    X = features
    y = target
    names = featname
    # fit an Extra Trees model to the data
    extree = ExtraTreesClassifier()
    extree.fit(X, y)
    # display the relative importance of each attribute
    print(sorted(zip(map(lambda x: round(x, 4), extree.feature_importances_), names)))

# %%
extree(d1m6,d1mtarget6,ft_nm_d1m6)
extree(d1m3,d1mtarget3,ft_nm_d1m3)

# %%
ex3030nop = [(0.1703, 'maxmonth1'), (0.0, 'TS605'), (0.0, 'antibiotic'), (0.0, 'avghfo_fio2'), (0.0, 'avglactate1_p1'), (0.0, 'avgph690'), (0.0, 'countcart'), (0.0, 'countcart_loc'), (0.0, 'countcart_p1'), (0.0, 'diffbmi'), (0.0, 'discharge - home lw'), (0.0, 'discharge - snf'), (0.0, 'maxIV_intake'), (0.0, 'maxabx_day_flag'), (0.0, 'maxabx_flag'), (0.0, 'maxabx_sum_1day'), (0.0, 'maxcdiff'), (0.0, 'maxcul_cathtip'), (0.0, 'maxdied01_p1'), (0.0, 'maxdied_ever'), (0.0, 'maxdied_ever_p1'), (0.0, 'maxencounter_masterdata'), (0.0, 'maxeverwardorICU'), (0.0, 'maxexpired'), (0.0, 'maxexpired_p1'), (0.0, 'maxgcs_score_sofa'), (0.0, 'maxhc03'), (0.0, 'maxhfo_fio2'), (0.0, 'maxicd9_558_3'), (0.0, 'maxinfxnqsofa'), (0.0, 'maxlactate1_p1'), (0.0, 'maxo2_device'), (0.0, 'maxpco2_1097'), (0.0, 'maxpco2_4098'), (0.0, 'maxph690'), (0.0, 'maxsepsis_antibiotic'), (0.0, 'maxsitter_order'), (0.0, 'maxtransfer_order_p1'), (0.0, 'maxtransrbc_gt1_p1'), (0.0, 'maxwardorICU'), (0.0, 'mincdiff'), (0.0, 'minheadneck_w_ct'), (0.0, 'minheadneck_wo_ct'), (0.0, 'minsofa_bili'), (0.0, 'minsofa_card'), (0.0, 'minsofa_gcs'), (0.0, 'sumcdiff')]
ex301rnop = [x[1] for x in ex3030nop]
extest3 = ex301rnop

# %%
d1m6 = df_los_60n[extest3]
d1m6 = d1m6.fillna(0)
#d1m6 = d1m6.iloc[0:]
d1mtarget6 = df_los_60_o['1m_read'].iloc[0:]#still df because rows have not changed
d1mtarget6 = d1mtarget6.astype(np.float64)
d1mtarget6 = d1mtarget6.fillna(0)
ft_nm_d1m6 = list(df_los_60n.columns)
d1m3 = df_los_30n[extest3]
d1m3 = d1m3.fillna(0)
#d1m3 = d1m3.iloc[0:]
d1mtarget3 = df_los_30_o['1m_read'].iloc[0:]#still df because rows have not changed
d1mtarget3 = d1mtarget3.astype(np.float64)
d1mtarget3 = d1mtarget3.fillna(0)
ft_nm_d1m3 = list(df_los_30n.columns)

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import AdaBoostClassifier
X = d1m3
y = d1mtarget3

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
clf = AdaBoostClassifier(n_estimators=200, random_state=0)
print(cross_val_score(clf, X, y, cv=skf, n_jobs=1))

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import GradientBoostingClassifier
X = d1m3
y = d1mtarget3
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
clf = GradientBoostingClassifier(n_estimators=200, learning_rate=1.0, max_depth=1, random_state=0)
print(cross_val_score(clf, X, y, cv=skf, n_jobs=1))
